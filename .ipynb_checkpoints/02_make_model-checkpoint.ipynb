# %%
from ultralytics import YOLO
from IPython.display import Image
import shutil
import numpy as np
import os

# %%
# デバイスの確認
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
# YOLOモデルの呼び出し
model = YOLO("yolov8x.pt")

# %%
# 学習
# results = model.train(data="C:/Users\yuuki/Kaggle/object_detection_try/aqualium_v2/data.yaml")
results = model.train(data="./data.yaml", epochs=10, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.2  Python-3.10.14 torch-2.2.2+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
# モデルの保存
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.2.2  Python-3.10.14 torch-2.2.2+cu118 CPU (13th Gen Intel Core(TM) i7-13700HX)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
#
# PyTorch: starting from 'runs\detect\train5\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (130.4 MB)
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success  4.3s, saved as 'runs\detect\train5\weights\best.onnx' (260.1 MB)
#
# Export complete (8.6s)
# Results saved to C:\Users\yuuki\Kaggle\object_detection_try\aqualium_v2\runs\detect\train5\weights
# Predict:         yolo predict task=detect model=runs\detect\train5\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train5\weights\best.onnx imgsz=640 data=./data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\train5\\weights\\best.onnx'

# %% [markdown]
# ## 結果の表示

# %%
# 混同行列
Image("runs/detect/train5/confusion_matrix.png")

# %%
precision = 197 / (197+3+1+4+254)
precision
# Out:
# 0.42919389978213507

# %%
recall = 197 /(197+3+2+1+86)
recall
# Out:
# 0.6816608996539792

# %%
# 正解
Image("runs/detect/train5/val_batch1_labels.jpg")

# %%
# 予測
Image("runs/detect/train5/val_batch1_pred.jpg")

# %%
# テストデータで推論
best_model = YOLO("runs/detect/train5/weights/best.pt")
best_model("data.yaml")
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 80, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(80, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(400, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !yolo detect val model=C:/Users/yuuki/Kaggle/object_detection_try/aqualium_v2/runs/detect/train5/weights/best.pt data=C:/Users/yuuki/Kaggle/object_detection_try/aqualium_v2/data.yaml split=test
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.14 torch-2.2.2+cu118 CPU (13th Gen Intel Core(TM) i7-13700HX)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: WARNING ⚠️ C:\Users\yuuki\Kaggle\object_detection_try\aqualium_v2\after_data\test\images\img63.jpg: ignoring corrupt image/label: cannot identify image file 'C:\\Users\\yuuki\\Kaggle\\object_detection_try\\aqualium_v2\\after_data\\test\\images\\img63.jpg'
# val: New cache created: C:\Users\yuuki\Kaggle\object_detection_try\aqualium_v2\after_data\test\labels.cache
#                    all         63        584      0.721      0.437      0.506      0.281
#                   fish         63        249      0.718      0.316      0.364      0.233
#              jellyfish         63        154      0.872      0.399      0.565      0.407
#                penguin         63         82      0.727      0.585      0.665      0.276
# ...

# %%
# 混同行列
Image("runs/detect/val/confusion_matrix.png")

# %%
# 正解
Image("runs/detect/val/val_batch2_labels.jpg")

# %%
# 予測
Image("runs/detect/val/val_batch2_pred.jpg")
